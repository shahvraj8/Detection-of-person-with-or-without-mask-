# %%
#First we will rename all the images and convert in to jpeg format by following code. Make sure that all the images and this notebook are in same folder.
import os
count = 0
for image in os.listdir():
  os.rename(image, str(count)+ "." + "jpeg")
  count+=1
